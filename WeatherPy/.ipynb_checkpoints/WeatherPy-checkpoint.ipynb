# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import base64
import json

# Import API key
def get_key(keyfile='config.py'):
    with open(keyfile,'rb') as inf:
        k = base64.b64decode(inf.read())
        inf.close()
    return k.decode('utf8')

weather_api_key = get_key()

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather"

units = "imperial"

query_url = url + "?appid=" + weather_api_key + "&units=" + units + "&q="

city_name = []
country = []
date = []
latitude = []
longitude = []
humidity = []
max_temp = []
wind_speed = []
cloudiness = []

record_count = 1

print("Beginning Data Retrieval")
print("--------------------------------")

for city in cities:
    weather_response = requests.get(query_url + city)
    try:
        weather_json = weather_response.json()
        
        city_name.append(weather_json["name"])
        country.append(weather_json["sys"]["country"])
        date.append(weather_json["dt"])
        latitude.append(weather_json["coord"]["lat"])
        longitude.append(weather_json["coord"]["lon"])
        humidity.append(weather_json["main"]["humidity"])
        max_temp.append(weather_json["main"]["temp_max"])
        wind_speed.append(weather_json["wind"]["speed"])
        cloudiness.append(weather_json["clouds"]["all"])
        
        city_record = weather_json["name"]
        
        print(f"Processing Record {record_count} | {city_record}")
        
        record_count += 1
        
    except:
        print("City not found. Skipping...")
        pass

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 | Galesong
# Processing Record 2 | Mar del Plata
# Processing Record 3 | Grimshaw
# Processing Record 4 | Nome
# Processing Record 5 | Albany
# Processing Record 6 | Barrow
# Processing Record 7 | Nordfjordeid
# Processing Record 8 | Carnarvon
# City not found. Skipping...
# Processing Record 9 | Lebu
# Processing Record 10 | Praia
# Processing Record 11 | Mataura
# Processing Record 12 | Rikitea
# City not found. Skipping...
# Processing Record 13 | Dudinka
# Processing Record 14 | Hong Kong
# Processing Record 15 | East London
# Processing Record 16 | Ribeira Grande
# Processing Record 17 | Tiznit Province
# Processing Record 18 | Haines Junction
# Processing Record 19 | Butaritari
# Processing Record 20 | Port-Gentil
# Processing Record 21 | Naliya
# Processing Record 22 | Norman Wells
# Processing Record 23 | Bilibino
# Processing Record 24 | Meulaboh
# City not found. Skipping...
# Processing Record 25 | Kamen'-Rybolov
# Processing Record 26 | Havre-St-Pierre
# Processing Record 27 | Vanimo
# Processing Record 28 | Imbituba
# Processing Record 29 | Omaruru
# Processing Record 30 | Ushuaia
# Processing Record 31 | Bengkulu
# Processing Record 32 | Wahiawā
# Processing Record 33 | Punta Arenas
# Processing Record 34 | Saint George
# Processing Record 35 | Avarua
# Processing Record 36 | Malbork
# Processing Record 37 | Busselton
# Processing Record 38 | Cherskiy
# City not found. Skipping...
# Processing Record 39 | Cape Town
# Processing Record 40 | Kapaa
# Processing Record 41 | Yangi Marg`ilon
# Processing Record 42 | Upernavik
# Processing Record 43 | Hobart
# Processing Record 44 | Tiksi
# Processing Record 45 | Jalu
# Processing Record 46 | Mezen'
# City not found. Skipping...
# Processing Record 47 | Icó
# Processing Record 48 | Mafinga
# Processing Record 49 | Vaini
# Processing Record 50 | Thompson
# Processing Record 51 | New Norfolk
# City not found. Skipping...
# Processing Record 52 | Chokurdakh
# Processing Record 53 | Abadan
# Processing Record 54 | Codrington
# Processing Record 55 | Praxédis Guerrero
# Processing Record 56 | Naryan-Mar
# Processing Record 57 | Pampa
# Processing Record 58 | Sitka
# City not found. Skipping...
# Processing Record 59 | Porto-Novo
# Processing Record 60 | Hermanus
# Processing Record 61 | Chara
# Processing Record 62 | Port Alfred
# Processing Record 63 | Dikson
# Processing Record 64 | Chui
# Processing Record 65 | Vostok
# Processing Record 66 | Khanbari
# Processing Record 67 | Lugovoy
# Processing Record 68 | Tres Arroyos
# Processing Record 69 | Itoman
# Processing Record 70 | College
# Processing Record 71 | Lompoc
# City not found. Skipping...
# Processing Record 72 | Husavik
# City not found. Skipping...
# Processing Record 73 | Nanortalik
# City not found. Skipping...
# Processing Record 74 | Atuona
# Processing Record 75 | Caxias do Sul
# Processing Record 76 | Beringovskiy
# Processing Record 77 | Bluff
# Processing Record 78 | Nioro
# Processing Record 79 | Bakreswar
# Processing Record 80 | Kavieng
# Processing Record 81 | Jamestown
# Processing Record 82 | Mareeba
# Processing Record 83 | São João da Barra
# Processing Record 84 | Atar
# Processing Record 85 | Souillac
# City not found. Skipping...
# Processing Record 86 | Ponta do Sol
# Processing Record 87 | Kaitangata
# Processing Record 88 | Pozo Colorado
# Processing Record 89 | Gorontalo
# Processing Record 90 | Deputatsky
# City not found. Skipping...
# Processing Record 91 | Yerbogachën
# Processing Record 92 | Kangāvar
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 93 | Arraial do Cabo
# Processing Record 94 | Mossamedes
# Processing Record 95 | Sinnamary
# Processing Record 96 | Saint Petersburg
# Processing Record 97 | Provideniya
# Processing Record 98 | Alofi
# Processing Record 99 | São Filipe
# Processing Record 100 | Saint-Joseph
# Processing Record 101 | Belaya Gora
# Processing Record 102 | Nikolskoye
# Processing Record 103 | Airai
# Processing Record 104 | Castro
# Processing Record 105 | Cayenne
# Processing Record 106 | Hilo
# Processing Record 107 | Yellowknife
# Processing Record 108 | Srednekolymsk
# Processing Record 109 | Cap Malheureux
# Processing Record 110 | Polovinnoye
# Processing Record 111 | Cabo San Lucas
# Processing Record 112 | Bundibugyo
# City not found. Skipping...
# Processing Record 113 | Krompachy
# Processing Record 114 | San Patricio
# Processing Record 115 | Bredasdorp
# Processing Record 116 | Vila Franca do Campo
# Processing Record 117 | Sovetskiy
# Processing Record 118 | Tuktoyaktuk
# Processing Record 119 | Mount Gambier
# Processing Record 120 | Lüderitz
# Processing Record 121 | Saint Paul Harbor
# City not found. Skipping...
# Processing Record 122 | Ouidah
# Processing Record 123 | San Quintín
# Processing Record 124 | Port Elizabeth
# Processing Record 125 | Esperance
# Processing Record 126 | Mitsamiouli
# Processing Record 127 | Khatanga
# City not found. Skipping...
# Processing Record 128 | Kudahuvadhoo
# Processing Record 129 | Nichinan
# Processing Record 130 | Bethel
# City not found. Skipping...
# Processing Record 131 | Florø
# Processing Record 132 | Lolodorf
# Processing Record 133 | Severo-Kuril'sk
# Processing Record 134 | Aksarka
# Processing Record 135 | Broome
# Processing Record 136 | Río Blanco
# City not found. Skipping...
# Processing Record 137 | Tsumeb
# Processing Record 138 | Tena
# City not found. Skipping...
# Processing Record 139 | Alexandria
# Processing Record 140 | Paracuru
# Processing Record 141 | Shumskiy
# Processing Record 142 | Longyearbyen
# Processing Record 143 | Ingham
# Processing Record 144 | Acaraú
# Processing Record 145 | Constantine
# Processing Record 146 | Clyde River
# Processing Record 147 | Preston
# City not found. Skipping...
# Processing Record 148 | Kruisfontein
# Processing Record 149 | Qaanaaq
# City not found. Skipping...
# Processing Record 150 | Ancud
# Processing Record 151 | Traian
# Processing Record 152 | Cedar City
# Processing Record 153 | Mount Isa
# Processing Record 154 | Talnakh
# City not found. Skipping...
# Processing Record 155 | Todos Santos
# Processing Record 156 | Olbia
# Processing Record 157 | Khani
# Processing Record 158 | Saint-Philippe
# Processing Record 159 | Mahajanga
# Processing Record 160 | Jumla
# Processing Record 161 | Polunochnoye
# Processing Record 162 | Ketchikan
# Processing Record 163 | Jardim
# Processing Record 164 | San Jose
# Processing Record 165 | Cidreira
# Processing Record 166 | Kabelvåg
# Processing Record 167 | Killybegs
# Processing Record 168 | Shimoga
# Processing Record 169 | São Miguel do Araguaia
# Processing Record 170 | Rawson
# City not found. Skipping...
# Processing Record 171 | Verkhnyaya Inta
# Processing Record 172 | Torbay
# Processing Record 173 | Harper
# Processing Record 174 | Ust-Tsilma
# Processing Record 175 | Baykit
# City not found. Skipping...
# Processing Record 176 | Los Llanos de Aridane
# Processing Record 177 | Krasnyy Yar
# Processing Record 178 | Badin
# Processing Record 179 | Ilulissat
# Processing Record 180 | Ulcinj
# Processing Record 181 | Kuril'sk
# Processing Record 182 | Morón
# Processing Record 183 | Sambava
# Processing Record 184 | Puerto Ayora
# Processing Record 185 | Aripuanã
# Processing Record 186 | Kosonsoy
# Processing Record 187 | Leningradskiy
# Processing Record 188 | Bangassou
# Processing Record 189 | Kenai
# Processing Record 190 | Shemursha
# Processing Record 191 | Talara
# Processing Record 192 | Bambous Virieux
# Processing Record 193 | Esil
# Processing Record 194 | Hithadhoo
# Processing Record 195 | Guerrero Negro
# Processing Record 196 | Dentsville
# Processing Record 197 | Naze
# City not found. Skipping...
# Processing Record 198 | Nova Odesa
# Processing Record 199 | Korla
# Processing Record 200 | Pisco
# Processing Record 201 | Mehamn
# Processing Record 202 | Hearst
# Processing Record 203 | Āsosa
# Processing Record 204 | Kvitok
# Processing Record 205 | Mozarlândia
# Processing Record 206 | Broken Hill
# Processing Record 207 | Opuwo
# Processing Record 208 | Coyhaique
# Processing Record 209 | Ukiah
# Processing Record 210 | Togur
# Processing Record 211 | Malakal
# Processing Record 212 | Saskylakh
# Processing Record 213 | Quatre Cocos
# Processing Record 214 | Lodja
# Processing Record 215 | Vardø
# Processing Record 216 | Igurusi
# Processing Record 217 | Havøysund
# Processing Record 218 | Mandalgovi
# Processing Record 219 | Sisimiut
# City not found. Skipping...
# Processing Record 220 | Shangrao
# Processing Record 221 | Lillooet
# Processing Record 222 | Grand Gaube
# Processing Record 223 | George Town
# Processing Record 224 | Nchelenge
# Processing Record 225 | Vista Hermosa
# Processing Record 226 | Beckley
# Processing Record 227 | Evensk
# Processing Record 228 | Tigil'
# Processing Record 229 | Ola
# Processing Record 230 | Pionki
# Processing Record 231 | Mizdah
# City not found. Skipping...
# Processing Record 232 | La Santisima Trinidad
# Processing Record 233 | Tairua
# Processing Record 234 | Fortuna
# Processing Record 235 | Dakar
# Processing Record 236 | Kontagora
# Processing Record 237 | Kimbe
# Processing Record 238 | Umluj
# Processing Record 239 | Palmer
# Processing Record 240 | Tasiilaq
# Processing Record 241 | Gorom-Gorom
# Processing Record 242 | Coos Bay
# City not found. Skipping...
# Processing Record 243 | Lima
# Processing Record 244 | San Vicente
# Processing Record 245 | Priyutovo
# Processing Record 246 | Haverfordwest
# Processing Record 247 | Aklavik
# Processing Record 248 | Kindu
# Processing Record 249 | Mahon
# Processing Record 250 | Masakin
# Processing Record 251 | Nizhniy Kuranakh
# City not found. Skipping...
# Processing Record 252 | High Level
# Processing Record 253 | Beyneu
# Processing Record 254 | Port Blair
# Processing Record 255 | Dodge City
# Processing Record 256 | Inongo
# Processing Record 257 | Linhares
# Processing Record 258 | Kpandae
# City not found. Skipping...
# Processing Record 259 | Taltal
# Processing Record 260 | Allāpalli
# City not found. Skipping...
# Processing Record 261 | Zhuanghe
# Processing Record 262 | Goderich
# Processing Record 263 | Tombouctou
# City not found. Skipping...
# Processing Record 264 | Osa
# Processing Record 265 | Willowmore
# Processing Record 266 | Sawtell
# Processing Record 267 | Riyadh
# Processing Record 268 | Jiazi
# Processing Record 269 | Dunedin
# Processing Record 270 | Santa Maria
# Processing Record 271 | Grand-Santi
# Processing Record 272 | Luganville
# Processing Record 273 | Marawi
# Processing Record 274 | Saint-Augustin
# Processing Record 275 | Half Moon Bay
# Processing Record 276 | Melioratorov
# Processing Record 277 | Lavrentiya
# Processing Record 278 | Harsūd
# Processing Record 279 | Teguise
# Processing Record 280 | Katsuura
# City not found. Skipping...
# Processing Record 281 | Salinópolis
# City not found. Skipping...
# Processing Record 282 | Chapais
# Processing Record 283 | Songkhla
# Processing Record 284 | Ostrovnoy
# Processing Record 285 | Zolochiv
# Processing Record 286 | Marsh Harbour
# Processing Record 287 | Hofn
# Processing Record 288 | Vila Velha
# Processing Record 289 | Kibala
# Processing Record 290 | San Joaquin
# Processing Record 291 | Mikhaylovka
# Processing Record 292 | Nuevo Laredo
# Processing Record 293 | Goryachegorsk
# Processing Record 294 | Alibag
# Processing Record 295 | Hualmay
# Processing Record 296 | Bulgan
# Processing Record 297 | Berlevåg
# Processing Record 298 | Ambunti
# Processing Record 299 | Pochutla
# Processing Record 300 | Panórama
# Processing Record 301 | Lashio
# Processing Record 302 | Ngunguru
# Processing Record 303 | Fairbanks
# Processing Record 304 | Panzhihua
# Processing Record 305 | Monteiro
# Processing Record 306 | Teya
# Processing Record 307 | Itacoatiara
# Processing Record 308 | Sotouboua
# Processing Record 309 | Kamakwie
# Processing Record 310 | Faanui
# Processing Record 311 | Tazmalt
# Processing Record 312 | Lagoa
# Processing Record 313 | Samarai
# City not found. Skipping...
# Processing Record 314 | Sur
# Processing Record 315 | Okhotsk
# Processing Record 316 | Yarim
# Processing Record 317 | Dingle
# Processing Record 318 | São Miguel
# Processing Record 319 | Fereydūnkenār
# Processing Record 320 | Bac Lieu
# Processing Record 321 | São Paulo de Olivença
# Processing Record 322 | Walvis Bay
# Processing Record 323 | Grand Bend
# Processing Record 324 | Keokuk
# Processing Record 325 | Saldanha
# Processing Record 326 | Bambanglipuro
# City not found. Skipping...
# Processing Record 327 | Rubtsovsk
# Processing Record 328 | Onega
# Processing Record 329 | Noumea
# City not found. Skipping...
# Processing Record 330 | Cabedelo
# Processing Record 331 | Shingū
# Processing Record 332 | Tyret’ Pervaya
# Processing Record 333 | Vestmannaeyjar
# Processing Record 334 | Salym
# Processing Record 335 | Sterling
# Processing Record 336 | Iqaluit
# Processing Record 337 | Marsá Maţrūḩ
# Processing Record 338 | Myitkyina
# City not found. Skipping...
# Processing Record 339 | Hay River
# City not found. Skipping...
# Processing Record 340 | Constitución
# Processing Record 341 | Ahipara
# Processing Record 342 | Waipawa
# Processing Record 343 | Enshi
# Processing Record 344 | Baruun-Urt
# Processing Record 345 | Eureka
# Processing Record 346 | Boissevain
# Processing Record 347 | Biloela
# Processing Record 348 | Tyulyachi
# Processing Record 349 | Mahébourg
# Processing Record 350 | Singaparna
# Processing Record 351 | Stepnyak
# Processing Record 352 | Doha
# Processing Record 353 | Suslovo
# Processing Record 354 | Santa Cruz de la Sierra
# Processing Record 355 | Gijón
# Processing Record 356 | Te Anau
# Processing Record 357 | Araguaína
# Processing Record 358 | Tiarei
# City not found. Skipping...
# Processing Record 359 | Phalodi
# Processing Record 360 | Hanmer Springs
# Processing Record 361 | Kungurtug
# Processing Record 362 | Kutum
# Processing Record 363 | Talcahuano
# Processing Record 364 | Río Gallegos
# Processing Record 365 | Lábrea
# City not found. Skipping...
# Processing Record 366 | Burnie
# Processing Record 367 | Wukari
# Processing Record 368 | Moosomin
# Processing Record 369 | Lorengau
# Processing Record 370 | Petropavlovsk-Kamchatskiy
# Processing Record 371 | Fontem
# Processing Record 372 | Asekeyevo
# Processing Record 373 | Hasaki
# Processing Record 374 | Avera
# Processing Record 375 | Geraldton
# Processing Record 376 | Kerema
# Processing Record 377 | Tuatapere
# Processing Record 378 | Mombetsu
# Processing Record 379 | Machinga
# Processing Record 380 | Lata
# Processing Record 381 | Acapulco de Juárez
# Processing Record 382 | Kununurra
# Processing Record 383 | Bontang
# Processing Record 384 | Rincon
# City not found. Skipping...
# Processing Record 385 | Neiafu
# Processing Record 386 | Carballo
# Processing Record 387 | Jussara
# Processing Record 388 | Iwaki
# Processing Record 389 | Isangel
# Processing Record 390 | Luoyang
# Processing Record 391 | Arrondissement de Mende
# Processing Record 392 | Catuday
# Processing Record 393 | Maki
# Processing Record 394 | Klaksvík
# Processing Record 395 | Bonavista
# Processing Record 396 | Laas
# City not found. Skipping...
# Processing Record 397 | Novikovo
# Processing Record 398 | Toamasina
# Processing Record 399 | Flin Flon
# Processing Record 400 | Cairns
# Processing Record 401 | Matara
# Processing Record 402 | Darnah
# Processing Record 403 | Nacala
# Processing Record 404 | Salalah
# Processing Record 405 | Obihiro
# Processing Record 406 | Yabēlo
# Processing Record 407 | Fuengirola
# Processing Record 408 | Turukhansk
# Processing Record 409 | Tecolutla
# Processing Record 410 | Harrisonville
# Processing Record 411 | Mehrān
# Processing Record 412 | Benguela
# Processing Record 413 | Khovu-Aksy
# Processing Record 414 | San Policarpo
# Processing Record 415 | Kushiro
# Processing Record 416 | Ormara
# City not found. Skipping...
# Processing Record 417 | Poum
# City not found. Skipping...
# Processing Record 418 | Xinan
# Processing Record 419 | Pastos Bons
# Processing Record 420 | Zalaegerszeg
# Processing Record 421 | Tegul'det
# Processing Record 422 | Ulladulla
# Processing Record 423 | Vaitape
# Processing Record 424 | Blythe
# Processing Record 425 | Diamantino
# Processing Record 426 | Kombissiri
# Processing Record 427 | Camacha
# Processing Record 428 | Bossangoa
# Processing Record 429 | Buluang
# Processing Record 430 | Rio Grande
# Processing Record 431 | Casper
# Processing Record 432 | Djambala
# Processing Record 433 | Port Lincoln
# Processing Record 434 | Amānganj
# Processing Record 435 | Ürümqi
# Processing Record 436 | Alyangula
# Processing Record 437 | Russell
# Processing Record 438 | Caratinga
# Processing Record 439 | San Cristobal
# Processing Record 440 | Raudeberg
# City not found. Skipping...
# Processing Record 441 | Asău
# Processing Record 442 | Dafeng
# City not found. Skipping...
# Processing Record 443 | Bathsheba
# Processing Record 444 | Zhanakorgan
# Processing Record 445 | Itarema
# City not found. Skipping...
# Processing Record 446 | Edd
# Processing Record 447 | Pervomayskiy
# Processing Record 448 | Cuamba
# Processing Record 449 | Estelle
# Processing Record 450 | Pevek
# Processing Record 451 | Jizan
# Processing Record 452 | Novonukutskiy
# Processing Record 453 | Ust-Nera
# Processing Record 454 | Honiara
# Processing Record 455 | Buchanan
# Processing Record 456 | Falam
# Processing Record 457 | Rimouski
# Processing Record 458 | Ambilobe
# Processing Record 459 | Olafsvik
# Processing Record 460 | Poddor'ye
# Processing Record 461 | Guéret
# Processing Record 462 | Laguna
# Processing Record 463 | Vrede
# Processing Record 464 | Nelson
# Processing Record 465 | Hammerfest
# City not found. Skipping...
# Processing Record 466 | Semporna
# Processing Record 467 | Zverinogolovskoye
# Processing Record 468 | Galle
# Processing Record 469 | Ransang
# Processing Record 470 | Rebrikha
# Processing Record 471 | Qui Nhon
# Processing Record 472 | Saravan
# City not found. Skipping...
# Processing Record 473 | Senno
# Processing Record 474 | Ponta Delgada
# Processing Record 475 | Waingapu
# Processing Record 476 | Lamu
# Processing Record 477 | Abu Dhabi
# Processing Record 478 | Stilfontein
# Processing Record 479 | Kokkola
# Processing Record 480 | Hawkesbury
# Processing Record 481 | Byron Bay
# Processing Record 482 | Fort-Shevchenko
# Processing Record 483 | Horta
# City not found. Skipping...
# Processing Record 484 | Tessalit
# Processing Record 485 | Karratha
# Processing Record 486 | Amapá
# Processing Record 487 | Yerköy
# Processing Record 488 | Rondonópolis
# Processing Record 489 | Zaozhuang
# Processing Record 490 | Tavatuy
# Processing Record 491 | Sørland
# Processing Record 492 | Kroya
# Processing Record 493 | Port Augusta
# Processing Record 494 | Cockburn Town
# Processing Record 495 | Yumen
# Processing Record 496 | Upington
# Processing Record 497 | Valdemārpils
# Processing Record 498 | Shubarshi
# Processing Record 499 | Abu Kamal
# Processing Record 500 | Andapa
# Processing Record 501 | Maniitsoq
# Processing Record 502 | Kasongo-Lunda
# Processing Record 503 | Sidi Ali
# Processing Record 504 | Mackay
# Processing Record 505 | Lüshunkou
# Processing Record 506 | Hamilton
# Processing Record 507 | Puerto Peñasco
# Processing Record 508 | Rocha
# Processing Record 509 | North Battleford
# Processing Record 510 | Balaka
# Processing Record 511 | Biak
# Processing Record 512 | Arrondissement de Vire
# Processing Record 513 | Honningsvåg
# Processing Record 514 | Ihosy
# Processing Record 515 | Mudgee
# Processing Record 516 | Forsytheganj
# Processing Record 517 | Flinders
# Processing Record 518 | Narsaq
# City not found. Skipping...
# Processing Record 519 | Morwa
# Processing Record 520 | Calderitas
# Processing Record 521 | Ugoofaaru
# Processing Record 522 | Ibiá
# Processing Record 523 | Calama
# City not found. Skipping...
# Processing Record 524 | Coolum Beach
# Processing Record 525 | Touros
# Processing Record 526 | Itaituba
# Processing Record 527 | Sinop Province
# Processing Record 528 | Sagua la Grande
# Processing Record 529 | Mayo
# Processing Record 530 | Tura
# Processing Record 531 | Yulara
# Processing Record 532 | Bay-Khaak
# Processing Record 533 | Chizhou
# Processing Record 534 | Prabumulih
# Processing Record 535 | Aitape
# Processing Record 536 | Tautira
# Processing Record 537 | Illescas
# Processing Record 538 | Boshkengash
# Processing Record 539 | Potoru
# Processing Record 540 | Naifaru
# Processing Record 541 | Margate
# Processing Record 542 | Xining
# Processing Record 543 | Kyzyl-Suu
# City not found. Skipping...
# Processing Record 544 | Kavaratti
# Processing Record 545 | Usinsk
# Processing Record 546 | San Andrés
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 547 | Ossora
# Processing Record 548 | Ouésso
# Processing Record 549 | Iracoubo
# Processing Record 550 | Loandjili
# Processing Record 551 | Mitchell
# Processing Record 552 | Balkanabat
# Processing Record 553 | Daru
# Processing Record 554 | Fichē
# Processing Record 555 | Kulu
# Processing Record 556 | Casa Grande
# Processing Record 557 | Khovd
# Processing Record 558 | Eirunepé
# Processing Record 559 | Fort Nelson
# Processing Record 560 | Puerto Madryn
# Processing Record 561 | Kamaishi
# Processing Record 562 | Yanam
# City not found. Skipping...
# Processing Record 563 | Portland
# Processing Record 564 | Turinsk
# Processing Record 565 | Seymchan
# Processing Record 566 | Verkhoyansk
# Processing Record 567 | Kalmunai
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(
    {"City": city_name,
     "Country": country,
     "Date" : date,
     "Latitude" : latitude,
     "Longitude" : longitude, 
     "Humidity" : humidity, 
     "Max Temp" : max_temp,
     "Wind Speed" : wind_speed,
     "Cloudiness" : cloudiness
    }
)

city_df.count()
# Out:
# City          567
# Country       567
# Date          567
# Latitude      567
# Longitude     567
# Humidity      567
# Max Temp      567
# Wind Speed    567
# Cloudiness    567
# dtype: int64

# %%
city_df.head()
# Out:
#             City Country        Date  Latitude  Longitude  Humidity  Max Temp  \
# 0       Galesong      ID  1584908956     -5.32     119.37       100     75.20
# 1  Mar del Plata      AR  1584908899    -38.00     -57.56        42     82.40
# 2       Grimshaw      CA  1584908956     56.18    -117.60        55     33.80
# 3           Nome      US  1584908956     64.50    -165.41        85     21.20
# 4         Albany      US  1584908956     42.60     -73.97        25     42.01
#
#    Wind Speed  Cloudiness
# 0        2.24          20
# 1        6.93          54
# 2        5.82          90
# 3        4.70          90
# 4        6.93          20

# %%
city_df.to_csv("output_data/city_data.csv", index = True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Max Temp"], edgecolors = "black")
plt.grid()
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/lat_maxtemp.png")
plt.show()

# %% [markdown]
# The scatter plot above showcases the relationship between latitude and temperature. As you can see from the graph, cities closer to the equator (0 degrees latitude) have higher temperatures than those away from the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Humidity"], edgecolors = "black")
plt.grid()
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/lat_humidity.png")
plt.show()

# %% [markdown]
# The scatter plot above showcases the relationship between latitude and hummidity. In this graph, we see no correlation between these two variables given the cities we have accounted for, although majority of the cities have higher humidity percentages.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Cloudiness"], edgecolors = "black")
plt.grid()
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/lat_cloudiness.png")
plt.show()

# %% [markdown]
# The scatter plot above showcases the relationship between latitude and cloudiness. Again here, we don't see a relationship between the two variables. Across the latitude range, we have some cities with 0% cloudiness and others with 100% cloudiness. The rest vary in their cloudiness depending on their latitudes.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Wind Speed"], edgecolors = "black")
plt.grid()
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/lat_windspeed.png")
plt.show()

# %% [markdown]
# The scatter plot above showcases the relationship between latitude and windspeed. We see that across latitude degrees, majority of the cities' wind speed ranges from 0 to 20 mph. The cities that exceed  well over 20 mph are the ones located in the northern hemisphere (towards the North Pole).

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
